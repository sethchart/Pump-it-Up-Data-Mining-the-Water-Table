# %% [markdown]
# ## Inspecting the Water Feature Group

# %%
from data_utilities import DataVisualization
viz = DataVisualization()
X_train = viz.X_train

# %% [markdown]
# There are no missing values in this group.

# %%
waterTable = X_train[['basin', 'water_quality', 'quality_group', 'quantity', 
    'source', 'source_type', 'source_class']]
waterTable.isnull().any()
# Out:
# basin            False
# water_quality    False
# quality_group    False
# quantity         False
# source           False
# source_type      False
# source_class     False
# dtype: bool

# %% [markdown]
# Below I have plotted the distribution of waterpoints with respect to each of the variables in this group. Notice that `water_quality` and `quality_group` have nearly identical distributions and values. Similarly, `source` and `source_type` have nearly identical distributions and values.

# %%
barplot_waterpoints(waterTable)

# %% [markdown]
# ## Conclusion
# Data in this group is complete. It seems likely that there is functional dependence between `water_quality` and `quality_group`. Similarly, there is likely a functional dependence between `source` and `source_type`.
